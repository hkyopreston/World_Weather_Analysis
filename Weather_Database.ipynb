# %%
# Import Dependencies

import pandas as pd
import gmaps
import requests
import numpy as np
from datetime import datetime
from citipy import citipy

# Import API key

from config import g_key
from config import weather_api_key

# %%
# import the requests library

from config import weather_api_key
from config import g_key

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# Create 1500 random latitudes and longitudes

lats = np.random.uniform(-90, 90, size = 1500)
lngs = np.random.uniform(-180, 180, size = 1500)

# Pack the lats and lngs as pairs by zipping them together

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and lngs to a list

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities

cities = []
city_data = []

# Identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list. 
    
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient count. 

len(cities)
# Out:
# 620

# %%
# Print the beginning of the logging. 

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.

record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        try: 
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try: 
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Current Description": city_weather_description,
                        "Rain (inches)": city_rain_inches,
                        "Snow (inches)": city_snow_inches,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lagoa
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | naryan-mar
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | whitefish
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | mayor pablo lagerenza
# Processing Record 14 of Set 1 | praia
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | san quintin
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | port-de-paix
# City not found. Skipping...
# Processing Record 23 of Set 1 | tevaitoa
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 1 | airai
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | boksitogorsk
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | bathsheba
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | tanete
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | balkhash
# Processing Record 38 of Set 1 | norfolk
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | bilma
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | esperance
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | richards bay
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | thunder bay
# Processing Record 1 of Set 2 | filadelfia
# Processing Record 2 of Set 2 | yining
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | ampanihy
# Processing Record 5 of Set 2 | tobol
# Processing Record 6 of Set 2 | ajdabiya
# Processing Record 7 of Set 2 | meulaboh
# Processing Record 8 of Set 2 | marquette
# Processing Record 9 of Set 2 | flinders
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | sambava
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | mao
# Processing Record 16 of Set 2 | tiarei
# Processing Record 17 of Set 2 | port macquarie
# Processing Record 18 of Set 2 | pangnirtung
# Processing Record 19 of Set 2 | luderitz
# Processing Record 20 of Set 2 | darhan
# Processing Record 21 of Set 2 | kushima
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | kuzino
# Processing Record 24 of Set 2 | tarauaca
# Processing Record 25 of Set 2 | lorengau
# Processing Record 26 of Set 2 | bandarbeyla
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | sisimiut
# Processing Record 29 of Set 2 | norman wells
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | constitucion
# Processing Record 32 of Set 2 | maraa
# Processing Record 33 of Set 2 | mogadishu
# Processing Record 34 of Set 2 | kaoma
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | skibbereen
# Processing Record 37 of Set 2 | panzhihua
# Processing Record 38 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 2 | kariba
# Processing Record 40 of Set 2 | zaysan
# Processing Record 41 of Set 2 | beloomut
# Processing Record 42 of Set 2 | saint-pierre
# Processing Record 43 of Set 2 | kermanshah
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | vallenar
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | faya
# Processing Record 1 of Set 3 | barcelos
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | ewa beach
# Processing Record 7 of Set 3 | namatanai
# Processing Record 8 of Set 3 | san felipe
# Processing Record 9 of Set 3 | vostok
# Processing Record 10 of Set 3 | kovdor
# Processing Record 11 of Set 3 | miranda
# Processing Record 12 of Set 3 | rocha
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | lompoc
# Processing Record 15 of Set 3 | saint-francois
# Processing Record 16 of Set 3 | los llanos de aridane
# Processing Record 17 of Set 3 | guane
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | dhidhdhoo
# Processing Record 20 of Set 3 | zhigansk
# Processing Record 21 of Set 3 | cabinda
# Processing Record 22 of Set 3 | half moon bay
# Processing Record 23 of Set 3 | puerto leguizamo
# Processing Record 24 of Set 3 | jamestown
# Processing Record 25 of Set 3 | kyra
# Processing Record 26 of Set 3 | maine-soroa
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | praia da vitoria
# Processing Record 29 of Set 3 | praxedis guerrero
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | hermanus
# Processing Record 33 of Set 3 | baykit
# Processing Record 34 of Set 3 | bonthe
# Processing Record 35 of Set 3 | xihua
# Processing Record 36 of Set 3 | kloulklubed
# Processing Record 37 of Set 3 | sarapulka
# Processing Record 38 of Set 3 | puerto escondido
# Processing Record 39 of Set 3 | san patricio
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | geraldton
# Processing Record 42 of Set 3 | leningradskiy
# Processing Record 43 of Set 3 | aliartos
# Processing Record 44 of Set 3 | clyde river
# Processing Record 45 of Set 3 | naze
# Processing Record 46 of Set 3 | luena
# Processing Record 47 of Set 3 | whitehorse
# Processing Record 48 of Set 3 | komsomolskiy
# Processing Record 49 of Set 3 | novi pazar
# Processing Record 50 of Set 3 | pilar
# Processing Record 1 of Set 4 | mayo
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | moose factory
# Processing Record 4 of Set 4 | souillac
# Processing Record 5 of Set 4 | dom pedrito
# Processing Record 6 of Set 4 | puri
# Processing Record 7 of Set 4 | pandan
# Processing Record 8 of Set 4 | san andres
# Processing Record 9 of Set 4 | chokurdakh
# Processing Record 10 of Set 4 | aleksandrov gay
# Processing Record 11 of Set 4 | kapaa
# Processing Record 12 of Set 4 | bathurst
# Processing Record 13 of Set 4 | hamilton
# Processing Record 14 of Set 4 | vanavara
# Processing Record 15 of Set 4 | broken hill
# Processing Record 16 of Set 4 | morehead
# Processing Record 17 of Set 4 | tarragona
# Processing Record 18 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | erzincan
# Processing Record 22 of Set 4 | rock springs
# Processing Record 23 of Set 4 | ostrovnoy
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | tadine
# Processing Record 26 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 4 | wyndham
# Processing Record 29 of Set 4 | husavik
# Processing Record 30 of Set 4 | dinghai
# Processing Record 31 of Set 4 | auki
# Processing Record 32 of Set 4 | aksum
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 4 | carmarthen
# Processing Record 36 of Set 4 | sao felix do xingu
# Processing Record 37 of Set 4 | avera
# Processing Record 38 of Set 4 | labuhan
# Processing Record 39 of Set 4 | santa maria del oro
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | saint anthony
# Processing Record 42 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 4 | muyezerskiy
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | muros
# Processing Record 46 of Set 4 | champerico
# Processing Record 47 of Set 4 | coihaique
# Processing Record 48 of Set 4 | kahului
# Processing Record 49 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 4 | marawi
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | inuvik
# Processing Record 3 of Set 5 | igarka
# Processing Record 4 of Set 5 | oranjemund
# Processing Record 5 of Set 5 | saint-philippe
# Processing Record 6 of Set 5 | padang
# Processing Record 7 of Set 5 | dickinson
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | orbetello
# Processing Record 10 of Set 5 | ascope
# Processing Record 11 of Set 5 | monrovia
# Processing Record 12 of Set 5 | saint-joseph
# Processing Record 13 of Set 5 | ixtapa
# Processing Record 14 of Set 5 | saint-augustin
# Processing Record 15 of Set 5 | klaksvik
# Processing Record 16 of Set 5 | nerchinskiy zavod
# Processing Record 17 of Set 5 | saint george
# Processing Record 18 of Set 5 | pacific grove
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | bartica
# Processing Record 21 of Set 5 | berlevag
# Processing Record 22 of Set 5 | takoradi
# Processing Record 23 of Set 5 | borba
# Processing Record 24 of Set 5 | ahipara
# Processing Record 25 of Set 5 | ponta do sol
# Processing Record 26 of Set 5 | kasangulu
# Processing Record 27 of Set 5 | koshurnikovo
# Processing Record 28 of Set 5 | yeppoon
# Processing Record 29 of Set 5 | shimanovsk
# Processing Record 30 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 32 of Set 5 | tura
# Processing Record 33 of Set 5 | kieta
# Processing Record 34 of Set 5 | natalinsk
# Processing Record 35 of Set 5 | novoagansk
# Processing Record 36 of Set 5 | tessalit
# Processing Record 37 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 5 | of
# City not found. Skipping...
# Processing Record 39 of Set 5 | san cristobal
# Processing Record 40 of Set 5 | comodoro rivadavia
# Processing Record 41 of Set 5 | sao jose da coroa grande
# Processing Record 42 of Set 5 | saldanha
# Processing Record 43 of Set 5 | weligama
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | romitan
# Processing Record 46 of Set 5 | contamana
# Processing Record 47 of Set 5 | verkhnya syrovatka
# Processing Record 48 of Set 5 | vila do maio
# Processing Record 49 of Set 5 | guarda
# Processing Record 50 of Set 5 | vershino-darasunskiy
# Processing Record 1 of Set 6 | gladstone
# Processing Record 2 of Set 6 | caracollo
# Processing Record 3 of Set 6 | north platte
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | kingman
# Processing Record 6 of Set 6 | pisco
# Processing Record 7 of Set 6 | bengkulu
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 6 | brigham city
# Processing Record 10 of Set 6 | beringovskiy
# Processing Record 11 of Set 6 | saint-georges
# Processing Record 12 of Set 6 | tambacounda
# Processing Record 13 of Set 6 | dajal
# Processing Record 14 of Set 6 | raga
# Processing Record 15 of Set 6 | fomboni
# Processing Record 16 of Set 6 | brainerd
# Processing Record 17 of Set 6 | burnie
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | fairhope
# Processing Record 20 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 6 | samandag
# Processing Record 22 of Set 6 | sheridan
# Processing Record 23 of Set 6 | dakar
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | haines junction
# Processing Record 26 of Set 6 | cururupu
# Processing Record 27 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 6 | sorland
# Processing Record 29 of Set 6 | mantena
# Processing Record 30 of Set 6 | salinas
# Processing Record 31 of Set 6 | tual
# Processing Record 32 of Set 6 | batsfjord
# Processing Record 33 of Set 6 | iisalmi
# Processing Record 34 of Set 6 | ucluelet
# Processing Record 35 of Set 6 | karratha
# Processing Record 36 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 37 of Set 6 | taunggyi
# Processing Record 38 of Set 6 | koryukivka
# Processing Record 39 of Set 6 | cherskiy
# Processing Record 40 of Set 6 | xunchang
# Processing Record 41 of Set 6 | waipawa
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | omsukchan
# Processing Record 44 of Set 6 | wana
# Processing Record 45 of Set 6 | portobelo
# Processing Record 46 of Set 6 | tiksi
# Processing Record 47 of Set 6 | babushkin
# Processing Record 48 of Set 6 | mnogovershinnyy
# Processing Record 49 of Set 6 | carnarvon
# Processing Record 50 of Set 6 | aksu
# Processing Record 1 of Set 7 | camacha
# Processing Record 2 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 7 | wattegama
# Processing Record 5 of Set 7 | vysokaya gora
# Processing Record 6 of Set 7 | samarai
# Processing Record 7 of Set 7 | bakchar
# Processing Record 8 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 7 | salisbury
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 7 | grand gaube
# Processing Record 13 of Set 7 | usinsk
# Processing Record 14 of Set 7 | sinazongwe
# Processing Record 15 of Set 7 | cabra
# Processing Record 16 of Set 7 | dikson
# Processing Record 17 of Set 7 | laguna
# Processing Record 18 of Set 7 | hambantota
# Processing Record 19 of Set 7 | sulangan
# Processing Record 20 of Set 7 | grojec
# Processing Record 21 of Set 7 | svetlogorsk
# Processing Record 22 of Set 7 | chuy
# Processing Record 23 of Set 7 | svelgen
# Processing Record 24 of Set 7 | mahajanga
# Processing Record 25 of Set 7 | krasnoselkup
# Processing Record 26 of Set 7 | witu
# Processing Record 27 of Set 7 | sioux lookout
# Processing Record 28 of Set 7 | soure
# Processing Record 29 of Set 7 | portland
# Processing Record 30 of Set 7 | joshimath
# Processing Record 31 of Set 7 | carutapera
# Processing Record 32 of Set 7 | hami
# Processing Record 33 of Set 7 | pervomayskiy
# Processing Record 34 of Set 7 | khandyga
# Processing Record 35 of Set 7 | broome
# Processing Record 36 of Set 7 | ziro
# Processing Record 37 of Set 7 | sabang
# Processing Record 38 of Set 7 | biak
# Processing Record 39 of Set 7 | cabo san lucas
# Processing Record 40 of Set 7 | mandalgovi
# Processing Record 41 of Set 7 | leninskoye
# Processing Record 42 of Set 7 | grindavik
# Processing Record 43 of Set 7 | roald
# Processing Record 44 of Set 7 | fremont
# Processing Record 45 of Set 7 | nishihara
# Processing Record 46 of Set 7 | honiara
# Processing Record 47 of Set 7 | birjand
# Processing Record 48 of Set 7 | rjukan
# Processing Record 49 of Set 7 | te anau
# Processing Record 50 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 8 | humpolec
# Processing Record 2 of Set 8 | saint-honore
# Processing Record 3 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 8 | uarini
# Processing Record 5 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 8 | normandin
# Processing Record 7 of Set 8 | harrisonville
# Processing Record 8 of Set 8 | ihosy
# Processing Record 9 of Set 8 | zolotkovo
# Processing Record 10 of Set 8 | doka
# Processing Record 11 of Set 8 | orlovskiy
# Processing Record 12 of Set 8 | vardo
# Processing Record 13 of Set 8 | minggang
# Processing Record 14 of Set 8 | ballina
# Processing Record 15 of Set 8 | wanning
# Processing Record 16 of Set 8 | vila franca do campo
# Processing Record 17 of Set 8 | singarayakonda
# Processing Record 18 of Set 8 | codrington
# Processing Record 19 of Set 8 | marystown
# Processing Record 20 of Set 8 | nanga eboko
# Processing Record 21 of Set 8 | myrtle beach
# Processing Record 22 of Set 8 | isla vista
# Processing Record 23 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 8 | baykalsk
# Processing Record 25 of Set 8 | wajima
# Processing Record 26 of Set 8 | port hardy
# Processing Record 27 of Set 8 | tocantinopolis
# City not found. Skipping...
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 8 | mugur-aksy
# Processing Record 31 of Set 8 | najran
# Processing Record 32 of Set 8 | plouzane
# Processing Record 33 of Set 8 | aswan
# Processing Record 34 of Set 8 | katsuura
# Processing Record 35 of Set 8 | cabo rojo
# Processing Record 36 of Set 8 | qaqortoq
# Processing Record 37 of Set 8 | coronado
# Processing Record 38 of Set 8 | ribeira grande
# Processing Record 39 of Set 8 | kokopo
# Processing Record 40 of Set 8 | batagay
# Processing Record 41 of Set 8 | moron
# Processing Record 42 of Set 8 | eyl
# Processing Record 43 of Set 8 | san policarpo
# Processing Record 44 of Set 8 | kirsanov
# Processing Record 45 of Set 8 | mastung
# Processing Record 46 of Set 8 | batagay-alyta
# Processing Record 47 of Set 8 | prince rupert
# Processing Record 48 of Set 8 | harper
# Processing Record 49 of Set 8 | ambur
# Processing Record 50 of Set 8 | penne
# Processing Record 1 of Set 9 | alyangula
# Processing Record 2 of Set 9 | lampa
# Processing Record 3 of Set 9 | lanxi
# Processing Record 4 of Set 9 | kaitangata
# Processing Record 5 of Set 9 | paragominas
# Processing Record 6 of Set 9 | gardner
# Processing Record 7 of Set 9 | alice springs
# Processing Record 8 of Set 9 | darab
# Processing Record 9 of Set 9 | opuwo
# Processing Record 10 of Set 9 | upernavik
# Processing Record 11 of Set 9 | vassouras
# Processing Record 12 of Set 9 | kurilsk
# Processing Record 13 of Set 9 | tieli
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | seka
# Processing Record 16 of Set 9 | casas grandes
# Processing Record 17 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 9 | launceston
# Processing Record 19 of Set 9 | sola
# Processing Record 20 of Set 9 | dzhebariki-khaya
# Processing Record 21 of Set 9 | bouna
# Processing Record 22 of Set 9 | morros
# Processing Record 23 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 9 | torrington
# Processing Record 25 of Set 9 | majene
# Processing Record 26 of Set 9 | vanderhoof
# Processing Record 27 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 9 | yumen
# Processing Record 29 of Set 9 | tilichiki
# Processing Record 30 of Set 9 | baherden
# Processing Record 31 of Set 9 | marsa matruh
# Processing Record 32 of Set 9 | itoman
# Processing Record 33 of Set 9 | chumikan
# Processing Record 34 of Set 9 | atasu
# Processing Record 35 of Set 9 | kiruna
# Processing Record 36 of Set 9 | chukhloma
# Processing Record 37 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 9 | umm kaddadah
# Processing Record 39 of Set 9 | shimoda
# Processing Record 40 of Set 9 | vao
# Processing Record 41 of Set 9 | sitka
# Processing Record 42 of Set 9 | pingliang
# Processing Record 43 of Set 9 | lavrentiya
# Processing Record 44 of Set 9 | conde
# Processing Record 45 of Set 9 | necochea
# Processing Record 46 of Set 9 | tumut
# Processing Record 47 of Set 9 | port hedland
# Processing Record 48 of Set 9 | riverton
# Processing Record 49 of Set 9 | buchanan
# Processing Record 50 of Set 9 | mezen
# Processing Record 1 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 10 | pangody
# Processing Record 3 of Set 10 | mweka
# Processing Record 4 of Set 10 | nazarovo
# Processing Record 5 of Set 10 | gashua
# Processing Record 6 of Set 10 | ancud
# Processing Record 7 of Set 10 | verkhoshizhemye
# Processing Record 8 of Set 10 | srednekolymsk
# Processing Record 9 of Set 10 | mocuba
# Processing Record 10 of Set 10 | ontario
# Processing Record 11 of Set 10 | riyadh
# Processing Record 12 of Set 10 | okhotsk
# Processing Record 13 of Set 10 | quatre cocos
# Processing Record 14 of Set 10 | eureka
# Processing Record 15 of Set 10 | buta
# Processing Record 16 of Set 10 | rio grande
# Processing Record 17 of Set 10 | fortuna
# Processing Record 18 of Set 10 | sarangani
# Processing Record 19 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 10 | along
# Processing Record 21 of Set 10 | mangai
# Processing Record 22 of Set 10 | charthawal
# Processing Record 23 of Set 10 | iralaya
# Processing Record 24 of Set 10 | mosetse
# Processing Record 25 of Set 10 | gizo
# Processing Record 26 of Set 10 | santa maria
# Processing Record 27 of Set 10 | rangapara
# Processing Record 28 of Set 10 | nanakuli
# Processing Record 29 of Set 10 | ust-tsilma
# Processing Record 30 of Set 10 | altay
# Processing Record 31 of Set 10 | qiqihar
# Processing Record 32 of Set 10 | ambilobe
# Processing Record 33 of Set 10 | christchurch
# Processing Record 34 of Set 10 | dundee
# Processing Record 35 of Set 10 | pimentel
# Processing Record 36 of Set 10 | kargopol
# Processing Record 37 of Set 10 | peniche
# Processing Record 38 of Set 10 | shkotovo-22
# City not found. Skipping...
# Processing Record 39 of Set 10 | aksarka
# Processing Record 40 of Set 10 | sur
# Processing Record 41 of Set 10 | lyubeshiv
# City not found. Skipping...
# Processing Record 42 of Set 10 | salinopolis
# Processing Record 43 of Set 10 | pelotas
# Processing Record 44 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 45 of Set 10 | honningsvag
# Processing Record 46 of Set 10 | asfi
# Processing Record 47 of Set 10 | moerai
# Processing Record 48 of Set 10 | san ramon
# Processing Record 49 of Set 10 | sabattus
# Processing Record 50 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 1 of Set 11 | tyazhinskiy
# Processing Record 2 of Set 11 | ambikapur
# Processing Record 3 of Set 11 | fairbanks
# Processing Record 4 of Set 11 | poya
# Processing Record 5 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 6 of Set 11 | conceicao da barra
# Processing Record 7 of Set 11 | jiazi
# Processing Record 8 of Set 11 | king city
# Processing Record 9 of Set 11 | akyab
# Processing Record 10 of Set 11 | vestmanna
# Processing Record 11 of Set 11 | waitati
# Processing Record 12 of Set 11 | kavaratti
# Processing Record 13 of Set 11 | ust-kulom
# Processing Record 14 of Set 11 | paris
# Processing Record 15 of Set 11 | gresham
# Processing Record 16 of Set 11 | atikokan
# Processing Record 17 of Set 11 | pouembout
# Processing Record 18 of Set 11 | kitami
# Processing Record 19 of Set 11 | westport
# Processing Record 20 of Set 11 | pathein
# Processing Record 21 of Set 11 | steinkjer
# Processing Record 22 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 23 of Set 11 | jalu
# Processing Record 24 of Set 11 | jaciara
# Processing Record 25 of Set 11 | antigonish
# Processing Record 26 of Set 11 | san isidro
# Processing Record 27 of Set 11 | torrijos
# Processing Record 28 of Set 11 | gobabis
# Processing Record 29 of Set 11 | zhanakorgan
# Processing Record 30 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 11 | alquizar
# Processing Record 32 of Set 11 | fort nelson
# Processing Record 33 of Set 11 | alvand
# Processing Record 34 of Set 11 | santiago de cuba
# Processing Record 35 of Set 11 | bambous virieux
# Processing Record 36 of Set 11 | mirabad
# Processing Record 37 of Set 11 | olafsvik
# Processing Record 38 of Set 11 | nokaneng
# Processing Record 39 of Set 11 | tabanan
# Processing Record 40 of Set 11 | cabedelo
# Processing Record 41 of Set 11 | palmer
# Processing Record 42 of Set 11 | big rapids
# Processing Record 43 of Set 11 | turukhansk
# Processing Record 44 of Set 11 | takob
# City not found. Skipping...
# Processing Record 45 of Set 11 | ossora
# Processing Record 46 of Set 11 | benguela
# Processing Record 47 of Set 11 | jaora
# Processing Record 48 of Set 11 | northam
# Processing Record 49 of Set 11 | moree
# Processing Record 50 of Set 11 | svetlyy
# Processing Record 1 of Set 12 | hay river
# Processing Record 2 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 3 of Set 12 | batemans bay
# Processing Record 4 of Set 12 | san jose
# Processing Record 5 of Set 12 | mecca
# Processing Record 6 of Set 12 | dingle
# Processing Record 7 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 8 of Set 12 | mehamn
# Processing Record 9 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 10 of Set 12 | srivardhan
# Processing Record 11 of Set 12 | vermillion
# Processing Record 12 of Set 12 | nouadhibou
# Processing Record 13 of Set 12 | hovd
# Processing Record 14 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 12 | sapa
# Processing Record 16 of Set 12 | hoquiam
# Processing Record 17 of Set 12 | raudeberg
# Processing Record 18 of Set 12 | virginia beach
# Processing Record 19 of Set 12 | kutum
# Processing Record 20 of Set 12 | dandong
# Processing Record 21 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 12 | la ronge
# Processing Record 23 of Set 12 | ponta delgada
# Processing Record 24 of Set 12 | egvekinot
# Processing Record 25 of Set 12 | tharad
# Processing Record 26 of Set 12 | lata
# Processing Record 27 of Set 12 | lannion
# Processing Record 28 of Set 12 | cheremukhovo
# Processing Record 29 of Set 12 | huilong
# Processing Record 30 of Set 12 | adre
# Processing Record 31 of Set 12 | sijunjung
# Processing Record 32 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 33 of Set 12 | kabinda
# Processing Record 34 of Set 12 | conyers
# Processing Record 35 of Set 12 | port augusta
# Processing Record 36 of Set 12 | price
# Processing Record 37 of Set 12 | jiangyou
# Processing Record 38 of Set 12 | sao joao da barra
# Processing Record 39 of Set 12 | namibe
# Processing Record 40 of Set 12 | sistranda
# Processing Record 41 of Set 12 | beloha
# Processing Record 42 of Set 12 | yambio
# Processing Record 43 of Set 12 | moultrie
# Processing Record 44 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 12 | jalostotitlan
# Processing Record 46 of Set 12 | nelson bay
# Processing Record 47 of Set 12 | smolenka
# Processing Record 48 of Set 12 | xuanzhou
# Processing Record 49 of Set 12 | pecos
# Processing Record 50 of Set 12 | nueve de julio
# Processing Record 1 of Set 13 | bereda
# Processing Record 2 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 3 of Set 13 | baripada
# Processing Record 4 of Set 13 | tongren
# Processing Record 5 of Set 13 | oksfjord
# Processing Record 6 of Set 13 | pringsewu
# Processing Record 7 of Set 13 | baturaja
# Processing Record 8 of Set 13 | uray
# Processing Record 9 of Set 13 | staritsa
# Processing Record 10 of Set 13 | sampit
# Processing Record 11 of Set 13 | piracuruca
# Processing Record 12 of Set 13 | gore
# Processing Record 13 of Set 13 | qandala
# Processing Record 14 of Set 13 | beboto
# Processing Record 15 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 16 of Set 13 | swan river
# Processing Record 17 of Set 13 | besancon
# Processing Record 18 of Set 13 | port keats
# Processing Record 19 of Set 13 | mangrol
# Processing Record 20 of Set 13 | zapolyarnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 565

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City    Lat     Lng  Max Temp Current Description  \
# 0             Lagoa  39.05  -27.98     65.26           clear sky
# 1             Bluff -46.60  168.33     39.00           clear sky
# 2      Longyearbyen  78.22   15.64     44.60       broken clouds
# 3    Severo-Kurilsk  50.68  156.12     41.92     overcast clouds
# 4           Rikitea -23.12 -134.97     75.97          light rain
# ..              ...    ...     ...       ...                 ...
# 560      Swan River  52.11 -101.27     46.71          light rain
# 561        Besancon  47.25    6.02     57.99           clear sky
# 562      Port Keats -14.25  129.55     69.62           clear sky
# 563         Mangrol  21.12   70.12     85.03          few clouds
# 564     Zapolyarnyy  69.42   30.81     53.60       broken clouds
#
#      Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0              0.0              0        88           4       13.65      PT
# 1              0.0              0        83           0        3.00      NZ
# 2              0.0              0        65          75        8.05      SJ
# 3              0.0              0        87         100        8.52      RU
# 4              0.8              0        85         100       17.60      PF
# ..             ...            ...       ...         ...         ...     ...
# 560            0.3              0        92         100        6.42      CA
# 561            0.0              0       100           0        1.10      FR
# 562            0.0              0        57           1        6.31      AU
# 563            0.0              0        79          13       15.95      IN
# 564            0.0              0        62          82        6.93      RU
#
# [565 rows x 11 columns]

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = sorted(city_data_df.columns.tolist())
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City  Cloudiness Country Current Description  Humidity    Lat  \
# 0             Lagoa           4      PT           clear sky        88  39.05
# 1             Bluff           0      NZ           clear sky        83 -46.60
# 2      Longyearbyen          75      SJ       broken clouds        65  78.22
# 3    Severo-Kurilsk         100      RU     overcast clouds        87  50.68
# 4           Rikitea         100      PF          light rain        85 -23.12
# ..              ...         ...     ...                 ...       ...    ...
# 560      Swan River         100      CA          light rain        92  52.11
# 561        Besancon           0      FR           clear sky       100  47.25
# 562      Port Keats           1      AU           clear sky        57 -14.25
# 563         Mangrol          13      IN          few clouds        79  21.12
# 564     Zapolyarnyy          82      RU       broken clouds        62  69.42
#
#         Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 0    -27.98     65.26            0.0              0       13.65
# 1    168.33     39.00            0.0              0        3.00
# 2     15.64     44.60            0.0              0        8.05
# 3    156.12     41.92            0.0              0        8.52
# 4   -134.97     75.97            0.8              0       17.60
# ..      ...       ...            ...            ...         ...
# 560 -101.27     46.71            0.3              0        6.42
# 561    6.02     57.99            0.0              0        1.10
# 562  129.55     69.62            0.0              0        6.31
# 563   70.12     85.03            0.0              0       15.95
# 564   30.81     53.60            0.0              0        6.93
#
# [565 rows x 11 columns]

# %%
city_data_df.dtypes
# Out:
# City                    object
# Cloudiness               int64
# Country                 object
# Current Description     object
# Humidity                 int64
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Rain (inches)          float64
# Snow (inches)            int64
# Wind Speed             float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head()
# Out:
#        City  Cloudiness Country Current Description  Humidity    Lat     Lng  \
# 4   Rikitea         100      PF          light rain        85 -23.12 -134.97
# 31   Tanete          99      ID          light rain        90  -3.94  119.78
# 41     Lebu         100      CL       moderate rain        94 -37.62  -73.65
# 48   Yining         100      CN          light rain        92  29.04  114.56
# 56  Sambava         100      MG          light rain        85 -14.27   50.17
#
#     Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 4      75.97           0.80              0       17.60
# 31     75.81           0.44              0        6.58
# 41     52.93           1.69              0       15.08
# 48     71.62           0.87              0        2.37
# 56     72.16           0.77              0       18.63

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head()
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Current Description, Humidity, Lat, Lng, Max Temp, Rain (inches), Snow (inches), Wind Speed]
# Index: []

# %%
# Create the output file (CSV)

output_data_file = "weather_data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
